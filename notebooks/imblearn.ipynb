# %% [markdown]
# ## IMBLearn Notebook
#
# This notebook holds iterations using sci-kit learn's imbalanced

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import pdfplumber
import tabula
import seaborn as sns
from Olympic_PED_use.src import functions as fn
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

from bs4 import BeautifulSoup
import certifi
import urllib3
import re
from csv import DictReader, DictWriter
import datetime as dt

import glob
import fuzzywuzzy
from fuzzywuzzy import fuzz

pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
# Out:
# /opt/anaconda3/envs/olympic-env/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def create_wiki_doping():
    
    '''This function creates the doping 
    dataframe containing athletes involved
    in doping irregularities (obtained from
    wikipedia)
    The functions fetches the html text and tags
    from the url and creates a dataframe using the 
    wiki_scraper function above. Then formats the 
    column values using the col_format function
    above. Finally, removing rows holding irrelevant
    values and replacing names with different spellings
    than in athlete dataframe with the appropriate spellings
    to match.'''
    
    url = 'https://en.wikipedia.org/wiki/List_of_doping_cases_in_athletics'
    req = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',
                         ca_certs=certifi.where())
    res = req.request('GET', url)
    soup = BeautifulSoup(res.data, 'html.parser')
    contents = soup.find_all('table', class_='wikitable sortable')  
    
    
    wiki_doping = fn.wiki_scraper(contents)

    wiki_doping = col_format(wiki_doping)

    wiki_doping.date_of_violation = [x.replace('23 May 2002  24 June 2002', '2002') for x in wiki_doping.date_of_violation]
    wiki_doping.date_of_violation = [x[:4] for x in wiki_doping.date_of_violation]

    drop_value = wiki_doping.date_of_violation[44]

    wiki_doping = wiki_doping[wiki_doping.date_of_violation != drop_value]
    wiki_doping = wiki_doping[wiki_doping.date_of_violation != 'Unkn']

    rows_to_drop = [0, 60, 197, 390, 632, 905, 1198, 1532, 1874, 1907, 2249,
                    2293, 2635, 2697, 3039, 3173, 3515, 3693, 4035, 4278, 4289,
                     4874, 4902, 5244, 5487, 5536, 5878, 6121, 6196, 6212,
                    6554, 6797, 6872, 6889, 7231, 7474, 7549, 7603, 7945, 8188,
                    8263, 8392,  8977, 9052, 9219, 9561, 9804, 9879, 10052,
                    10637, 10712, 10907, 11249, 11492, 11567, 11789, 12131,
                    12374, 12449, 12672, 13014, 13257, 13332, 13914, 14157, 14232]

    wiki_doping = wiki_doping.drop(rows_to_drop, axis=0)

    wiki_doping.date_of_violation = [int(x) for x in wiki_doping.date_of_violation]

    wiki_doping.drop_duplicates(inplace=True)


    wiki_names = list(wiki_doping.name.unique())

    wiki_doping = wiki_doping.sort_values(by='name')

    wiki_doping = wiki_doping[wiki_doping.date_of_violation > 2003]

    wiki_doping = wiki_doping[wiki_doping.date_of_violation < 2017]

    wiki_doping.reset_index(drop=True, inplace=True)

# %%
athlete_df = pd.read_csv('../data/athletes_dataset/athlete_events.csv')
athlete_df.columns = [x.lower() for x in athlete_df.columns]

# %%
athlete_df = athlete_df.loc[athlete_df.sport == 'Athletics']

# %%
athlete_df = athlete_df.loc[athlete_df.year > 2002]
athlete_df = athlete_df.loc[athlete_df.year < 2018]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Men's 4 x 100 metres Relay"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Men's 4 x 400 metres Relay"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Women's 4 x 100 metres Relay"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Women's 4 x 400 metres Relay"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Men's Marathon"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Women's Marathon"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Women's 4 x 100 metres Relay"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Women's Heptathlon"]
athlete_df = athlete_df.loc[athlete_df.event != "Athletics Men's Decathlon"]

# %%
athlete_names = list(athlete_df.name.unique())
doping_names = list(doping_df.name.unique())

# %%
def match_names(term, list_names, min_score=0):
    max_score = -1
    max_name = ''
    for x in list_names:
        score = fuzz.ratio(term, x)
        if (score > min_score) & (score > max_score):
            max_name = x
            max_score = score
    return (max_name, max_score)

# %%
dict_list = []
for x in doping_names:
    match = match_names(x, athlete_names, 70)
    print('"{}":"{}",'.format(x,match[0]))
    dict_ = {}
    dict_.update({'doping_name': x})
    dict_.update({'match_name': match[0]})
    dict_.update({'score': match[1]})
    dict_list.append(dict_)
# Out:
# "Abdelatif Chemlal":"Abdelatif Chemlal",
# "Abdelhadi Habassa":"",
# "Abdelhadi Labäli":"",
# "Abdelkader Hachlaf":"Abdelkader Hachlaf",
# "Abdellah Haidane":"Abdellah Falil",
# "Abderrahim El Asri":"Abderrahim Al-Goumri",
# "Abderrahim Goumri":"Abderrahim Al-Goumri",
# "Abderrahhime Bouramdane":"",
# "Abdulagadir Idriss":"",
# "Abraham Kiprotich":"Abraham Kipchirchir Rotich",
# "Abubaker Ali Kamal":"Abubaker Ali Kamal",
# "Adil Kaouch":"Adil El-Kaouch",
# "Adrián Annus":"Adrin Zsolt Annus",
# "Adriënne Herzog":"",
# "Agatha Jeruto Kimaswai":"",
# "Agnieszka Gortel-Maciuk":"",
# "Agustín Félix":"",
# "Ahmad Hazer":"Ahmad Hazer",
# "Ahmed Abd El Raouf":"",
# "Ahmed Baday":"",
# "Ahmed Faiz":"Ahmed Ali",
# "Ahmed Mohamed Dheeb":"",
# "Ak Hafiy Tajuddin Rositi":"Ak Hafiy Tajuddin Rositi",
# "Alberico Di Cecco":"",
# "Aleksandr Bulanov":"Aleksandar Rakovi",
# "Aleksandr Vashchilo":"",
# "Aleksandra Duliba":"",
# "Aleksey Korolev":"Aleksey Pogorelov",
# "Aleksey Lesnichy":"Aleksey Lesnichy",
# "Aleksey Voyevodin":"Aleksey Nikolayevich Voyevodin",
# "Alemayehu Bezabeh":"Alemayehu Bezabeh Desta",
# "Alemitu Bekele":"Alemitu Bekele Degfa",
# "Alessandra Aguilar":"",
# "Alex Schwazer":"Alex Schwazer",
# "Alex Trembach":"",
# "Ali Ekber Kayas":"",
# "Alice Decaux":"",
# "Alicia Brown":"Alicia Brown",
# "Alyona Dubitskaya":"",
# "Alissa Kallinikou":"Alissa Kallinikou",
# "Allison Randall":"Allison Randall",
# "Allodin Fothergill":"",
# "Alvin Harrison":"",
# "Amaia Piedra":"",
# "Amaka Ogoegbunam":"Amaka Ogoegbunam",
# "Amantle Montsho":"Amantle Montsho",
# "Ambesse Tolosa":"",
# "Mina Aït Hammou":"Amina "Mina" At Hammou",
# "Amina Bakhit":"Amina Barsham Bakhit",
# "Amine Laâlou":"Amine Lalou",
# "Tasos Gousis":"",
# "Anastasiya Kapachinskaya":"Anastasiya Aleksandrovna Kapachinskaya",
# "Anastasiya Soprunova":"Anastasiya Valeryevna Soprunova",
# "Anastasiya Kudinova":"Anastasiya Valeryevna Kudinova",
# "Anca Heltne":"",
# "Andreas Gustafsson":"",
# "Andrei Varantsou":"",
# "Andrey Rudnitskiy":"",
# "Andrey Ruzavin":"",
# "Andriy Yurin":"",
# "Anil Kumar Sangwan":"Anil Kumar Sangwan",
# "Anis Ananenko":"",
# "Anna Alminova":"",
# "Anna Avdeyeva":"",
# "Anna Gurova":"",
# "Anna Mishchenko":"",
# "Anthony Alozie":"",
# "Anton Galkin":"Antonn alsk",
# "Antonello Petrei":"",
# "Antonina Yefremova":"Antonina Oleksandrivna Yefremova",
# "Antonio Jiménez":"",
# "Anzhelika Shevchenko":"Anzhelika Viktorivna Shevchenko",
# "Anália Rosa":"",
# "Arnaud Casquette":"",
# "Artur Osman":"",
# "Asafa Powell":"Asafa Kehine Powell",
# "Ashwini Akkunji":"",
# "Aslı Çakır":"",
# "Atalelech Ketema":"",
# "Athanasia Tsoumeleka":"Athanasia Tsoumeleka",
# "Ato Modibo":"",
# "Attila Szabó":"",
# "Awatef Ben Hassine":"",
# "Ayman Kozhakhmetova":"Ayman Bulatovna Kozhakhmetova",
# "Aziz Lahbabi":"Aziz Lahbabi",
# "Abdul Aziz Zakari":"Abdul Aziz Zakari",
# "Aïssa Dghoughi":"",
# "Bahar Doğan":"",
# "Barakat Al-Harthi":"Barakat Mubarak Al-Harthi",
# "Benjamin Kipkurui":"Beniamin Kuciski",
# "Bernard Williams Iii":"Bernard Rollen Williams, III",
# "Bertrand Moulinet":"Bertrand Moulinet",
# "Bimbo Miel Ayedou":"",
# "Binnaz Uslu":"Binnaz Uslu",
# "Bobby-Gaye Wilkins":"",
# "Bola Gee Lawal":"",
# "Bouchra Ghezielle":"",
# "Boštjan Šimunič":"Botjan imuni",
# "Brian Mariano":"",
# "Bruno Lins":"",
# "Béranger Bosse":"Branger Aymard Bosse",
# "Callum Priestley":"",
# "Carmen Zamfir-Gilhase":"",
# "Cathal Lombard":"",
# "Cecilia Francis":"",
# "Chakir Boujattaoui":"",
# "Chaltu Beji":"",
# "Chinaza Amadi":"",
# "Chris Lukezic":"",
# "Christine Ohuruogu":"Christine Arron",
# "Chris Williams":"Chrishuna Williams",
# "Christy Ekpukhon":"",
# "Cordera Jenkins":"",
# "Corina Dumbrăvean":"",
# "Cristina Vasiloiu":"",
# "Cristinel Irimia":"",
# "Cyrus Njui":"",
# "Cédric Nabe":"",
# "Damian Kusiak":"",
# "Damien Broothaerts":"",
# "Daniela Yordanova":"Daniela Lyubenova Yordanova",
# "Darya Pishchalnikova":"Darya Vitalyevna Pishchalnikova",
# "Darya Pizhankova":"",
# "Darya Safonova":"Darya Maslova",
# "Debbie Dunn":"",
# "Deborah Oluwaseun Odeyemi":"",
# "Demetra Arachoviti":"",
# "Denis Alekseyev":"Denis Sergeyevich Alekseyev",
# "Diego Palomeque":"",
# "Dimitrios Khondrokoukis":"Dimitrios Chondrokoukis",
# "Dimitrios Regas":"Dimitrios Serelis",
# "Dmitriy Sorokin":"Dmitri Marin",
# "Dmytro Kosynskiy":"",
# "Dominique Blake":"",
# "Dorian Scott":"Dorian Armand Scott",
# "Dmitri Marşin":"Dmitri Marin",
# "Ebrahim Rahimian":"Ebrahim Rahimian",
# "Edder Moreno":"",
# "Eddy Hellebuyck":"",
# "Edi Maia":"Edi Silva Maia",
# "Eduard Mbengani":"",
# "Eirini Kokkinariou":"Eirini Kokkinariou",
# "Ekaterina Ishova (Ekaterina Gorbunova)":"",
# "Ekaterina Medvedeva":"",
# "Ekaterini Thanou":"",
# "Elena Antoci":"",
# "Yelena Arzhakova":"Yelena Vladimirovna Arzhakova",
# "Elena Lashmanova":"",
# "Elena Meuti":"",
# "Elias Bastos":"",
# "Elif Yildirim":"",
# "Elizabeth Muthuka":"",
# "Emily Chebet":"Winny Chebet",
# "Enrique Llanos":"Enrique Llanos",
# "Erick Walder":"Erik Cade",
# "Erik Tysse":"Erik Tysse",
# "Eşref Apak":"Eref Apak",
# "Esther Akinsulie":"",
# "Euclides Varela":"",
# "Eva-Maria Gradwohl":"",
# "Eyerusalem Kuma":"",
# "Fani Halkia":"Fani Khalkia",
# "Fathi Meftah":"",
# "Fatih Eryildirim":"",
# "Fatima Yvelain":"",
# "Femi Ogunode":"Femi Seun Ogunode",
# "Fernando Silva":"",
# "Flomena Chepchirchir":"",
# "Florent Lacasse":"Florent Lacasse",
# "Shade Abugan":"",
# "Fouad El-Kaam":"Fouad El-Kaam",
# "Francisca Koki  Koki Manunga":"",
# "Frédéric Denis":"",
# "Funke Adeoye":"",
# "Gareth Warburton":"Gareth Robert Warburton",
# "Geisa Arcanjo":"Geisa Rafaela Arcanjo",
# "Geraldine Hendricken":"",
# "Gergely Horváth":"Gergely Horvth",
# "Gergely Palágyi":"",
# "Geronimo Goeloe":"Geronimo Goeloe",
# "Ghfran Mouhamad":"Ghfran Al-Mouhamad",
# "Ghofrane Mohammad":"Ghfran Al-Mouhamad",
# "Gilmar Lopes":"",
# "Gladys Tejeda":"",
# "Gloria Amuche Nwosu":"",
# "Gloria Kemasuode(Gloria Ubiebor)":"Gloria E. Kemasuode (-Ubiebor)",
# "Gregory Sedoc":"Grzegorz Sudo",
# "Gulustan Ieso":"",
# "Gwen Berry":"Gwen Berry",
# "Géza Pauer":"Gza Pauer",
# "Hafid Chani":"",
# "Halima Hachlaf":"Halima Hachlaf",
# "Halina Karnatsevich":"",
# "Hamid Ezzine":"Hamid Ezzine",
# "Hamza Driouch":"Hamza Al-Driouch",
# "Hanane Ouhaddou":"Hanane Ouhaddou",
# "Hanna Drabenia":"",
# "Hassan Hirt":"Hassan Hirt",
# "Hassan Mourhit":"Hassan Hirt",
# "Hayat El Ghazi":"",
# "Hector Carrasquillo":"",
# "Hélder Ornelas":"",
# "Helena Javornik":"Helena Javornik",
# "Hezekiél Sepeng":"Hezekiel Sello Sepeng",
# "Hind Déhiba":"",
# "Hristina Risteska":"Hristina Risteska",
# "Hristoforos Hoidis":"",
# "Hristos Polihroniou":"",
# "Hrysopiyi Devetzi":"Khrysopigi "Pigi" Devetzi",
# "Huang Qun":"Huang Qun",
# "Hussain Al-Hamdah":"Hussain Jamaan Al-Hamdah",
# "Hussein Awada":"",
# "Héni Kechi":"",
# "Igor Vinichenko":"",
# "Igor Yerokhin":"",
# "Ildar Minshin":"",
# "Ilja Nikolajev":"",
# "Ilya Konovalov":"",
# "Inga Abitova":"",
# "Inika Mcpherson":"Inika McPherson",
# "Inna Eftimova":"",
# "Ioan Vieru":"",
# "Irina Khudoroshkina":"Irina Aleksandrovna Khudoroshkina",
# "Irina Maracheva":"",
# "Irina Meleshina":"",
# "Irina Timofeyeva":"",
# "Irina Yumanova":"",
# "Irina Yatchenko":"Irina Vasilyevna Yatchenko",
# "Ion Emilianov":"Ion Emilianov",
# "Ivan Gertlein":"",
# "Ivan Tsikhan":"",
# "Ivanildo dos Anjos":"",
# "Ivory Williams":"Conrad Williams",
# "Iván Hierro":"",
# "Jaanus Uudmäe":"",
# "Jake Freeman":"David Freeman",
# "Jamel Chatbi":"",
# "James Kibocha Theuri":"James Kwalia Chepkurui",
# "Jani Chathurangani Silva":"",
# "Jarrod Bannister":"Jarrod Bannister",
# "Jauna Murmu":"",
# "Jaysuma Saidy Ndure":"Jaysuma Saidy Ndure",
# "Jeremias Saloj":"",
# "Jessica Cosby":"",
# "Jill Camarena-Williams":"Jillian Mary "Jill" Camarena-Williams",
# "Jimmy Melfort":"",
# "John Capel":"",
# "Jolanda Čeplak":"",
# "Jon Drummond":"",
# "Josephine Onyia":"Josephine Nnkiruka Onyia",
# "Joshua Ross":"Joshua James Ross",
# "Josiane Tito":"",
# "José Alessandro Bagio":"Jos Alessandro Bernardo Baggio",
# "José Luis Blanco":"Jos Luis Blanco Quevedo",
# "José Rocha":"",
# "Joy Nakhumicha Sakari":"Joy Nakhumicha Sakari",
# "João Gabriel Sousa":"",
# "Julia Mumbi Muraga":"",
# "Julie Coulaud":"Julie Culley",
# "Julien Dunkley":"Julie Culley",
# "Julien Kapek":"Julien-Pierre Kapek",
# "Kagisho Kumbane":"",
# "Kaltouma Nadjina":"Kaltouma Nadjina",
# "Karin Melis":"Karin Melis (Mey-)",
# "Yekaterina Belanovich":"",
# "Kenta Bell":"Kenwood Kenta Bell",
# "Kevin Rans":"",
# "Khalid Choukoud":"",
# "Khalid Tighazouine":"",
# "Khalid Zoubaa":"",
# "Kirill Ikonnikov":"",
# "Kofi Amoah Prah":"",
# "Kostas Baniotis":"",
# "Kostas Filippidis":"",
# "Kostas Kenteris":"",
# "Kseniya Ryzhova":"",
# "LaMark Carter":"Mark Carroll",
# "Lashawn Merritt":"LaShawn Merritt",
# "Laverne Jones":"",
# "Lada Chernova":"",
# "Laiyuan Gao":"",
# "Lansford Spence":"",
# "Larbi Bouraada":"",
# "Larry Wade":"",
# "Latifa Essarokh":"Latifa Essarokh",
# "Lawretta Ozoh":"",
# "Laïla Traby":"",
# "Lebogang Phalula":"Lebogang Shange",
# "Lee Evans":"",
# "Leevan Sands":"Leevan Sands",
# "Leonardo Elisiário dos Santos":"",
# "Lidiya Grigoryeva":"",
# "Liliana Popescu":"Elena Popescu",
# "Liliya Shobukhova":"",
# "Lim Eun-ji":"",
# "Lim Hee-nam":"",
# "Lindsey Scherf":"",
# "Lisa Kehler":"",
# "Lisa Nemec":"",
# "Liu Hong":"Liu Hong",
# "Liza Hunter-Galvan":"",
# "Lucimar Teodoro":"Lucimar Teodoro",
# "Lucimara da Silva":"",
# "Luis Collazo":"",
# "Luketz Swartbooi":"",
# "Luvo Manyonga":"Luvo Manyonga",
# "Lydia Cheromei":"",
# "Lyubov Denisova":"",
# "Lyubov Ivanova(Lyubov Kharlamova)":"",
# "Lyubov Perepelova":"Lyubov Gennadyevna Perepelova",
# "Lyudmyla Yosypenko":"",
# "Lu Huihui":"Lu Huihui",
# "Mahdi Zamani":"",
# "Malika Asahssah":"",
# "Mamorallo Tjoka":"",
# "Mandeep Kaur":"Mandeep Kaur",
# "Marcelo Pugliese":"Marcelo Adrin Pugliese",
# "Margarita Fuentes-Pila":"",
# "Marielis Rojas":"",
# "Mariem Alaoui Selsouli":"Mariem Alaoui Selsouli",
# "Marin Premeru":"",
# "Marina Marghiev-Nicișenco":"Marina Marghiev-Nicienco",
# "Mariya Bespalova":"",
# "Mariya Konovalova":"",
# "Mariya Ryemyen":"",
# "Mariya Yakovenko":"Mariya Ivanovna Yakovenko",
# "Mark Jelks":"",
# "Mark Lewis-Francis":"Mark Anthony Lewis-Francis",
# "Marta Dominguez":"Marta Domnguez Azpeleta",
# "Martin Fagan":"Martin Tian",
# "Martin Marić":"Martin Mari",
# "Marvin Anderson":"Marvin Anderson",
# "Marwa Hussein":"Kariem Hussein",
# "Mary Akor Basley":"",
# "Masoud Azizi":"Masoud Azizi",
# "Mathew Kipkoech Kisorio":"",
# "Maude Mathys":"",
# "Mehmet Çağlayan":"",
# "Meliz Redif":"",
# "Meryem Erdogan":"",
# "Meryem Khali":"",
# "Michael Berry":"Michal Balner",
# "Michael Velter":"Michal Balner",
# "Michal Balner":"Michal Balner",
# "Mikhalis Stamatogiannis":"Mikhalis Stamatogiannis",
# "Miguel Ángel Gamonal":"",
# "Mihaela Botezan":"Mihaela Maria Botezan",
# "Mike Rodgers":"",
# "Mikhail Lemaev":"",
# "Mikko Kyyrö":"",
# "Mikołaj Lewański":"",
# "Milan Haborák":"Milan Habork",
# "Milan Jotanović":"",
# "Mimi Belete":"",
# "Mohamed El-Hachimi":"Mohamed El-Hachimi",
# "Mohammad Noor Imran Abdul Hadi":"",
# "Mohammed Shaween":"Mohammed Othman H. Shaween",
# "Monzavous Edwards":"",
# "Mostafa Errebbah":"",
# "Mouhcine Cheaouri":"",
# "Monira Alsaleh":"",
# "Musa Amer":"",
# "Nabil Kirame":"",
# "Nadezhda Vorobieva":"",
# "Nadia Noujani":"Nadia Noujani",
# "Nadezhda Ostapchuk":"Nadezhda Nikolayevna Ostapchuk",
# "Nailiya Yulamanova":"Nadiya Dusanova",
# "Najim El Qady":"",
# "Naman Keïta":"",
# "Nataliia Lupu":"Nataliya Oleksivna Lupu",
# "Nataliya Pyhyda":"Nataliya Serhivna Pyhyda",
# "Nataliya Tobias":"Nataliya Asanova",
# "Natallia Kareiva":"",
# "Natallia Mikhnevich":"",
# "Natasha Mayers":"Natasha Laren Mayers",
# "Ndiss Kaba Badji":"Ndiss Kaba Badji",
# "Neelam Jaswant Singh Dogra":"Neelam Jaswant Singh Dogra",
# "Nemanja Kojić":"",
# "Nevin Yanıt":"Nevin Yant",
# "Nicolas Figère":"Nicolas Figre",
# "Nikolai Vedehin":"",
# "Nilay Esen":"",
# "Noraldo Palacios":"",
# "Nordine Gezzar":"",
# "Norjannah Hafiszah Jamaludin":"",
# "Nuno da Costa":"",
# "Ofentse Mogawane":"",
# "Oksana Verner":"",
# "Oksana Yarygina":"",
# "Oleksandr Dryhol":"",
# "Oleksandr Korchmid":"Oleksandr Mykolaiovych Korchmid",
# "Oleksiy Shelest":"Oleksiy Petrovych Shelest",
# "Olena Antonova":"Olena Anatolivna Antonova",
# "Olesya Syreva":"",
# "Olga Cristea":"Olga Cristea",
# "Olga Golovkina":"Olga Bolova",
# "Olga Kaniskina":"",
# "Olga Kuzenkova":"Olga Sergeyevna Kuzenkova",
# "Olga Shchukina":"Olga Shchukina",
# "Olga Tereshkova":"Olga Alekseyevna Tereshkova",
# "Olga Yegorova":"Olga Bolova",
# "Olha Zemlyak":"",
# "Damola Osayomi":"",
# "Toyin Augustus":"Olutoyin "Toyin" Augustus",
# "Omolara Omotosho":"Omolara Omotosho",
# "Onalenna Baloyi":"Onalenna Oabona Baloyi",
# "Paquillo Fernández":"",
# "Pascal Mancini":"",
# "Pauline Kahenya":"Pauline Kwalea",
# "Pavel Krivitsky":"Pavel Eduardovich Krivitsky",
# "Paweł Rakoczy":"Pawe Rakoczy",
# "Petr Bogatyrev":"",
# "Piotr Lisek":"Piotr Lisek",
# "Pınar Saka":"Pnar Saka",
# "Quentin Bigot":"Quentin Bigot",
# "Rachid El-Ghanmouni":"",
# "Rachid Nadij":"",
# "Rael Kiyara":"",
# "Rajendra Bahadur Bhandari":"Rajendra Bahadur Bhandari",
# "Ramolefi Motsieloa":"",
# "Rashid Ramzi":"",
# "Ray Stewart":"",
# "Recep Çelik":"Recep elik",
# "Remigius Machura (born 1986)":"",
# "Rhys Williams":"Rhys Williams",
# "Ricardo Fernández":"",
# "Richard Mavuso":"",
# "Ridouane Es-Saadi":"",
# "Ridouane Harroufi":"",
# "Rita Jeptoo":"",
# "Rkia El Moukim":"",
# "Robert Kajuga":"Robert Kajuga",
# "Roland Varga":"Roland Robert Varga",
# "Roman Avramenko":"",
# "Roman Usov":"Romana Malov",
# "Ronald Rutto":"",
# "Rosa Rodríguez":"",
# "Roxana Elisabeta Bîrcă":"Roxana Elisabeta Brc",
# "Ruddy Zang-Milama":"",
# "Ruqaya Al-Ghasra":"Rakia Al-Gassra",
# "Róbert Fazekas":"Rbert Fazekas",
# "Sabine Heitling":"",
# "Sadaf Siddiqui":"Sadaf Siddiqui",
# "Sammy Alex Mutahi":"",
# "Samson Idiata":"",
# "Samuel Okon":"",
# "Sandra Perković":"Sandra Perkovi",
# "Sara Moreira":"",
# "Sara Ramadhani":"",
# "Saurav Vij":"",
# "Saïda El Mehdi":"",
# "Scott Boothby":"",
# "Sebastian Varga":"Sebastian Bayer",
# "Seltana Aït Hammou":"Seltana At Hammou",
# "Semiha Mutlu":"Semiha Mutlu",
# "Semoy Hackett":"Semoy Kee-Ann Hackett",
# "Serene Ross":"Desiree Rossit",
# "Sergey Bakulin":"Sergey Pakura",
# "Sergey Kirdyapkin":"",
# "Sergey Morozov":"Sergey Chernov",
# "Sergio Sanchez":"",
# "Sergiu Ursu":"",
# "Shawn Crawford":"Shawn Crawford",
# "Shawn Barber":"Alana Barber",
# "Shelly-Ann Fraser-Pryce":"Shelly-Ann Fraser-Pryce",
# "Sherone Simpson":"Sherone Anmarica Simpson",
# "Shitaye Gemechu":"",
# "Silvano Chesani":"Silvano Chesani",
# "Simon Magakwe":"",
# "Simone Alves da Silva":"",
# "Sini Jose":"",
# "Siyabonga Nkonde":"",
# "Song Hongjuan":"Song Hongjuan",
# "Stanislav Melnykov":"Stanislav Anatoliyovych Melnykov",
# "Steve Mullings":"",
# "Sultan Mubarak Al-Dawoodi":"Sultan Mubarak M. Al-Dawoodi",
# "Sun Yingjie":"Sun Yingjie",
# "Surita Febbraio":"Surita Febbraio (Loots-)",
# "Susan Chepkemei":"Nancy Chepkwemoi",
# "Susanne Pumper":"",
# "Suzette Lee":"",
# "Svetlana Biryukova":"Svetlana Bolshakova",
# "Svetlana Cherkasova":"Svetlana Pessova",
# "Svetlana Klyuka":"Svetlana Vasilyevna Klyuka",
# "Svetlana Krivelyova":"Svetlana Vladimirovna Krivelyova",
# "Svitlana Shmidt":"",
# "Sébastien Denis":"",
# "Süreyya Ayhan":"",
# "Tahesia Harrigan-Scott":"Tahesia Gaynell Harrigan-Scott",
# "Tameka Williams":"Tameka Williams",
# "Tatyana Aryasova":"Tatyana Borisova",
# "Tatyana Chernova":"Tatyana Borisova",
# "Tatyana Dektyareva":"Tatyana Valeryevna Dektyareva",
# "Tatyana Kotova":"Tatyana Borisova",
# "Tatyana Lysenko":"Tatyana Yefimenko",
# "Tatyana Mineeva":"Tatyana Borisova",
# "Tatyana Tomashova":"Tatyana Borisova",
# "Tayeb Kalloud":"",
# "Teddy Tamgho":"",
# "Teodora Kolarova":"",
# "Tetiana Petliuk":"Tetiana Hryhorivna Petliuk",
# "Tetyana Hamera-Shmyrko":"",
# "Tezeta Dengersa":"",
# "Tezdzhan Naimova":"Tezdzhan Naimova",
# "Thomas Goller":"Thomas Rhler",
# "Thozama April":"",
# "Timothy Rusan":"",
# "Torri Edwards":"Darvin Edwards",
# "Tosin Adeloye":"",
# "Traves Smikle":"Traves Jamie Smikle",
# "Tsholofelo Thipe":"Tsholofelo Thipe (Selemela-)",
# "Tuğçe Şahutoğlu":"Tue ahutolu",
# "Tyson Gay":"",
# "Tânia Spindler":"",
# "Valentin Kruglyakov":"",
# "Valeriy Borchin":"Valeriy Viktorovich Borchin",
# "Vanda Gomes":"Sandra Gomis",
# "Vanya Stambolova":"Vania Emilova Stambolova",
# "Vanja Perišić":"Vanja Perii",
# "Venelina Veneva-Mateeva":"Venelina Ivanova Veneva-Mateeva",
# "Victor Hogan":"",
# "Viktor Burayev":"",
# "Ville Tiisanoja":"Ville Johannes Tiisanoja",
# "Vivian Chukwuemeka":"Vivian Peters-Chukwuemeka",
# "Vladimir Andreyev":"Leonid Vladimirovich Andreyev",
# "Vladimir Kanaykin":"Vladimir Alekseyevich Kanaykin",
# "Vladimir Sasimovich":"Vladimir Savanovi",
# "Vukosava Đjapić":"",
# "Víctor Castillo":"",
# "Wafa Ismail El Baghdadi":"",
# "Wallace Spearmon":"Wallace Spearmon, Jr.",
# "Walter Davis":"Walter L. Davis",
# "Wang Jiali":"Wang Jianan",
# "Wang Jing":"Wang Jing",
# "Wang Lina":"Wang Lina",
# "Wang Shizhu":"",
# "Wilson Loyanae":"",
# "Wilson Loyanae Erupe":"",
# "Yahya Berrabah":"Yahya Berrabah",
# "Yarelys Barrios":"Yarelis Barrios Castaeda",
# "Yassine Bensghir":"Yassine Bensghir",
# "Yekaterina Khoroshikh":"",
# "Yekaterina Kostetskaya":"Yekaterina Aleksandrovna Kostetskaya",
# "Yelena Churakova":"Yelena Anatolyevna Churakova",
# "Yelena Prokhorova":"Yelena Parfyonova",
# "Yelena Ryabova":"elena Rabowa",
# "Yelena Soboleva":"Yelena Smolyanova",
# "Yeliz Kurt":"",
# "Yelizaveta Grechishnikova":"Yelizaveta Andriyanovna Grechishnikova",
# "Yelyzaveta Bryzhina":"Yelyzaveta Viktorivna Bryzhina",
# "Yevgeniya Pecherina":"",
# "Yevgeniya Zinurova":"",
# "Yevhen Vynohradov":"Yevhen Valeriyovych Vynohradov",
# "Yin Anna":"Yin Anna",
# "Yoel Tapia":"",
# "Yohan Blake":"Yohan Blake",
# "Yolanda Caballero":"",
# "Yolanda Osana":"",
# "Yousef Masrahi":"Yousef Ahmed Al-Masrahi",
# "Yu-Fang Hsu":"",
# "Yuliya Balykina":"",
# "Yuliya Fomenko":"",
# "Yuliya Leantsiuk":"",
# "Yuliya Ruban":"",
# "Yuliya Rusanova":"Nadiya Dusanova",
# "Yuliya Zaripova":"",
# "Yuriy Andronov":"",
# "Yuriy Bilonoh":"",
# "Zahra Bouras":"Zahra Bani",
# "Zalina Marghiev":"",
# "Zhang Qi":"Zhang Li",
# "Zohar Zemiro":"",
# "Zoltán Kővágó":"Zoltn Kvg",
# "Zudikey Rodríguez":"",
# "Ángel Mullera":"ngel Mullera Rodrguez",
# "Ümmü Kiraz":"",
# "Živilė Balčiūnaitė":"",
